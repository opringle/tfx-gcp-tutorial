# %%
import pandas as pd

# %%
df = pd.read_csv('../datasets/petfinder-mini/petfinder-mini.csv')

# %%
# keys are features values are pandas series
df_dict = dict(df)
for key, feature in df_dict.items():
    print("Key is {}\tFeatures:\n\n{}\n".format(key, feature))
# Out:
# Key is Type	Features:
#
# 0        Cat
# 1        Cat
# 2        Dog
# 3        Dog
# 4        Dog
#         ...
# 11532    Dog
# 11533    Cat
# 11534    Dog
# 11535    Cat
# 11536    Dog
# Name: Type, Length: 11537, dtype: object
#
# Key is Age	Features:
#
# 0         3
# 1         1
# 2         1
# 3         4
# 4         1
#          ..
# 11532    24
# 11533     1
# 11534     6
# 11535     9
# 11536     1
# Name: Age, Length: 11537, dtype: int64
#
# Key is Breed1	Features:
#
# 0                       Tabby
# 1        Domestic Medium Hair
# 2                 Mixed Breed
# 3                 Mixed Breed
# 4                 Mixed Breed
#                  ...
# 11532                  Poodle
# 11533     Domestic Short Hair
# 11534               Schnauzer
# 11535     Domestic Short Hair
# 11536             Mixed Breed
# Name: Breed1, Length: 11537, dtype: object
#
# Key is Gender	Features:
#
# 0          Male
# 1          Male
# 2          Male
# 3        Female
# 4          Male
# ...
